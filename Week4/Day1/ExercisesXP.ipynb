# %% [markdown]
# # **Exercises XP**

# %% [markdown]
# **Exercise 1: Introduction To Data Analysis. Objective: Understand The Basic Overview And Significance Of Data Analysis.**
#
# In the ever-evolving landscape of technology and information, data analysis has emerged as a crucial tool for extracting meaningful insights from vast datasets.
# It encompasses a set of techniques and processes aimed at inspecting, cleaning, transforming, and modeling data to uncover useful information, draw conclusions, and support decision-making.
# Data analysis is the systematic examination of data sets to discover meaningful patterns, trends, and information.
# It involves the use of various statistical and mathematical techniques, often aided by specialized software tools, to process and interpret raw data.
# The primary objective of data analysis is to transform complex data into actionable insights, aiding organizations and individuals in making informed decisions and predictions.
# In the digital age, where data is generated at an unprecedented rate, the importance of data analysis cannot be overstated.
# Organizations across diverse industries leverage data analysis to enhance their decision-making processes, optimize operations, and gain a competitive edge.
# The key reasons behind the significance of data analysis include:
# Informed Decision Making:
# Data analysis provides a foundation for informed decision-making.
# By analyzing historical and real-time data, businesses can identify patterns, market trends, and consumer behavior, empowering them to make strategic decisions that align with their goals and objectives.
# Operational Efficiency:
# Businesses use data analysis to streamline operations and improve efficiency. By analyzing internal processes and performance metrics, organizations can identify bottlenecks, optimize workflows, and enhance overall productivity.
# Predictive Analytics:
# Data analysis facilitates predictive analytics, allowing organizations to forecast future trends and outcomes.
# This is particularly valuable in areas such as finance, healthcare, and marketing, where accurate predictions can lead to more effective planning and resource allocation.

# %% [markdown]
# **Exercise 2: Dataset Loading And Initial Analysis**
#
# Objective: Practice Dataset Loading From Kaggle And Initial Analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

# %%
file1 = r'C:\Users\Acer\Desktop\Time Americans Spend Sleeping.csv'
df1 = pd.read_csv(file1)

file2 = r'C:\Users\Acer\Desktop\Mental health Depression disorder Data.csv'
df2 = pd.read_csv(file2)

file3 = r'C:\Users\Acer\Desktop\clean_dataset.csv'
df3 = pd.read_csv(file3)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8952\3076864914.py:5: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(file2)

# %%
df1.head(10)
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
# 5      5  2008  Annual                      8.60           0.023     All days
# 6      6  2009  Annual                      8.67           0.023     All days
# 7      7  2010  Annual                      8.67           0.024     All days
# 8      8  2011  Annual                      8.71           0.026     All days
# 9      9  2012  Annual                      8.73           0.026     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# ...

# %%
df2.head(10)
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
# 5      5  Afghanistan  AFG  1995          0.160076             0.698695
# 6      6  Afghanistan  AFG  1996          0.160249             0.698914
# 7      7  Afghanistan  AFG  1997          0.160554             0.699127
# 8      8  Afghanistan  AFG  1998          0.160931             0.699372
# 9      9  Afghanistan  AFG  1999          0.161311             0.699674
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# ...

# %%
df3.head(10)
# Out:
#    Gender    Age    Debt  Married  BankCustomer               Industry  \
# 0       1  30.83   0.000        1             1            Industrials
# 1       0  58.67   4.460        1             1              Materials
# 2       0  24.50   0.500        1             1              Materials
# 3       1  27.83   1.540        1             1            Industrials
# 4       1  20.17   5.625        1             1            Industrials
# 5       1  32.08   4.000        1             1  CommunicationServices
# 6       1  33.17   1.040        1             1              Transport
# 7       0  22.92  11.585        1             1  InformationTechnology
# 8       1  54.42   0.500        0             0             Financials
# 9       1  42.50   4.915        0             0            Industrials
#
#   Ethnicity  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 0     White          1.250             1         1            1
# ...

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **A brief description of the data**
# - The "Time Americans Spend Sleeping" table contains 9 columns and 945 rows. The columns contain information about the year, period, average sleep duration per day, age group, gender, activity, and others.
#
# - The Mental health Depression disorder table contains 11 columns and 108553 rows. The columns contain information about the country, year, and percentage of a particular type of mental disorder.
#
# - The "Credit Card Approvals" table contains 16 columns and 690 rows. The columns contain information about gender, age, amount of debt, whether a person is married, industry, years of work, credit rating and others.

# %% [markdown]
# **Exercise 3: Identifying Data Types**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **categorize each column of it as either quantitative or qualitative**
# - In the "Time Americans Spend Sleeping" table, the quantitative columns are Avg hrs per day sleeping, Standard Error (float type). The qualitative columns are Year (integer type), Period, Type of Days, Age Group, Activity, Sex (object type). Because quantitative data can be compared, mathematical operations can be performed, and qualitative data are categories.
#
# - In the "Mental health Depression" table, the quantitative columns are Schizophrenia (%), Bipolar disorder (%), Eating disorders (%), Anxiety disorders (%), Drug use disorders (%) , Depression (%), Alcohol use disorders (%), as they represent percentage values and can be they are considered as numerical. The qualitative columns are Year, Entity, and Code, as they represent categorical values.
#
# - In the "Credit Card Approvals" table, the quantitative columns are Debt, Income, as they represent numeric values and mathematical operations can be performed with them. The qualitative columns are Gender, Age, Gender, BankCustomer, Industry, Ethnicity, YearsEmployed, PriorDefault, Employed, CreditScore, DriversLicense, Citizen, ZipCode, Approved as they represent categorical values.

# %% [markdown]
# **Exercise 4: Exploring Data Types**
#
# Objective: Learn About Different Types Of Data In Data Analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.

# %%
file4 = r'C:\Users\Acer\Desktop\IRIS.csv'
df4 = pd.read_csv(file4)

# %%
df4.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **categorize each column of it as either quantitative or qualitative**
#
# Quantitative data: sepal_length, sepal_width, petal_length, petal_width, as they are represented by numerical values, most likely measured in centimeters.
# Qualitative data: species, as represented by categorical values denoting the type of plant.

# %% [markdown]
# **Exercise 5: Basic Data Analysis**
# Objective: Perform Basic Data Analysis Using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries.

# %%
from scipy import stats

mean_sepal_length = df4['sepal_length'].mean()
median_sepal_length = df4['sepal_length'].median()
mode_sepal_length = stats.mode(df4['sepal_length']).mode[0]

print(f"Mean sepal length: {mean_sepal_length:.2f}")
print(f"Median sepal length: {median_sepal_length}")
print(f"Mode sepal length: {mode_sepal_length}")
# Out:
# Mean sepal length: 5.84
# Median sepal length: 5.8
# Mode sepal length: 5.0
# C:\Users\Acer\AppData\Local\Temp\ipykernel_8952\1962440567.py:5: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_sepal_length = stats.mode(df4['sepal_length']).mode[0]

# %%
import seaborn as sns

plt.figure(figsize=(6, 4))
sns.histplot(df4['sepal_length'], bins=10, kde=True)

plt.title('Distribution of sepal length', fontsize=12)
plt.xlabel('Sepal Length (cm)', fontsize=8)
plt.ylabel('Frequency', fontsize=8)

plt.show()

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# - The mean and median of the sepal length are almost equal, which means that there are no abnormal values among the values.
# - The histogram illustrates that most often the sepal length is 4.7-5, 5.5-5.7, 6-6,5 cm.

# %% [markdown]
# **Exercise 6: Basic Observation Skills In Data Analysis**
#
# Objective: Develop Observation Skills For Data Analysis.
# Task: Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison).

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# - Year: trend analysis.
# The "Year" column provides temporal information. Analyzing trends over the years can reveal patterns, changes, or fluctuations in the average hours of sleep. This could be useful for understanding how sleep patterns have evolved over time.
#
# - Avg hrs per day sleeping: trend analysis, group comparison.
# This column represents the average hours of sleep per day. Analyzing the trends in average sleep duration over the years can provide insights into sleep patterns. Additionally, comparing sleep durations across different age groups or genders (if applicable) can help identify variations.
#
# - Age Group: group comparison.
# The "Age Group" column categorizes the data into different age groups. Analyzing sleep patterns across age groups can help identify if there are significant differences in average hours of sleep. This may be particularly relevant for understanding sleep behavior in different life stages.
#
# - Sex: group comparison.
# The "Sex" column categorizes the data by gender. Analyzing sleep patterns based on gender can help identify any gender-specific differences in average hours of sleep.
