# %% [markdown]
# # Daily Challenge: Advanced Data Analysis And Problem Solving With SciPy And NumPy

# %% [markdown]
# ## Task: Given a complex, multi-dimensional dataset, apply advanced transformation and analysis techniques to extract meaningful insights.
# Objective: This exercise aims to test your ability to think creatively and apply various SciPy and NumPy functions in a complex, real-world-like scenario.
# Dataset: A dataset representing a scientific experiment with multiple variables (e.g., temperature, pressure, and chemical concentration) measured over time. The dataset should have at least 1000 entries and multiple variables.

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import pearsonr, spearmanr
from scipy.stats import linregress
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Seed for reproducibility
np.random.seed(0)

# Number of entries
n_entries = 1000

# Simulating dataset
time = np.linspace(0, 100, n_entries)  # Time variable
temperature = 20 + 5 * np.sin(np.pi * time / 50) + np.random.normal(0, 0.5, n_entries)  # Temperature (with some noise)
pressure = 1013 + 20 * np.cos(np.pi * time / 25) + np.random.normal(0, 1, n_entries)  # Pressure (with some noise)
chemical_concentration = 5 + 2 * np.sin(np.pi * time / 10) + np.random.normal(0, 0.2, n_entries)  # Chemical concentration

# Creating DataFrame
ninja_data = pd.DataFrame({
    'Time': time,
    'Temperature': temperature,
    'Pressure': pressure,
    'Chemical Concentration': chemical_concentration
})

ninja_data.head(10)
# Out:
#        Time  Temperature     Pressure  Chemical Concentration
# 0  0.000000    20.882026  1033.555963                4.693416
# 1  0.100100    20.231526  1033.890892                4.720490
# 2  0.200200    20.552262  1032.571356                5.134934
# 3  0.300300    21.214783  1033.090475                4.996730
# 4  0.400400    21.059555  1033.202742                5.234754
# 5  0.500501    19.668572  1033.161935                5.172408
# 6  0.600601    20.663684  1033.483838                5.220976
# 7  0.700701    20.144382  1031.104440                5.340547
# 8  0.800801    20.199863  1032.849494                5.638584
# 9  0.900901    20.488174  1033.111004                5.744355

# %% [markdown]
# ### 1. Data Transformation:
#
# Goal: Prepare the data for analysis by applying transformations.
# Steps and Hints:
# Normalization: Transform the data so that each variable has a mean of 0 and standard deviation of 1. Use numpy for calculations.
# Logarithmic Scaling (Optional): Apply logarithmic scaling if the data has a wide range of values. This can be done using np.log.
# Fourier Transformation: Utilize Fourier transformation to analyze frequency components in the data. This can be insightful for time-series data.
# Tools: Explore np.fft.fft for Fourier transformation.

# %%
# Normalization
normalized_data = (ninja_data - ninja_data.mean()) / ninja_data.std()

# Logarithmic Scaling
log_scaled_data = np.log1p(ninja_data)

# Fourier Transformation
fourier_transform = np.fft.fft(ninja_data['Temperature'])

# %% [markdown]
# ### 2. Statistical Analysis:
#
# Goal: Extract statistical insights from the data.
# Steps and Hints:
# Descriptive Statistics: Use pandas describe() function to get an overview of the data.
# Correlation Analysis: Calculate and interpret the correlation between variables using pandas corr() function.
# Inferential Statistics: Consider conducting hypothesis tests or regression analysis to draw deeper insights.
# Tools: Explore scipy.stats for advanced statistical functions.

# %%
# Descriptive Statistics
descriptive_stats = ninja_data.describe()

# Correlation Analysis
correlation_matrix = ninja_data.corr()

# Inferential Statistics (Linear Regression)
slope, intercept, r_value, p_value, std_err = linregress(ninja_data['Time'], ninja_data['Temperature'])

print("Descriptive statistics:")
display(descriptive_stats)

print("\nCorrelation matrix:")
display(correlation_matrix)

print("\nLinear regression results:")
print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"P-value: {p_value:.4f}")
print(f"R-squared value: {r_value**2:.4f}")
# Out:
# Descriptive statistics:
#               Time  Temperature     Pressure  Chemical Concentration
# count  1000.000000  1000.000000  1000.000000             1000.000000
# mean     50.000000    19.977372  1013.033617                4.989754
# std      28.910854     3.574943    14.203350                1.436505
# min       0.000000    13.897407   990.284418                2.559310
# 25%      25.000000    16.386984   998.852247                3.576024
# 50%      50.000000    20.008666  1012.950967                4.970976
# 75%      75.000000    23.570373  1027.062114                6.398067
# max     100.000000    26.030294  1035.471676                7.486763
# Correlation matrix:
#                             Time  Temperature  Pressure  \
# Time                    1.000000    -0.770696 -0.001946
# Temperature            -0.770696     1.000000  0.007112
# Pressure               -0.001946     0.007112  1.000000
# Chemical Concentration -0.156113    -0.003277 -0.000863
#
# ...

# %% [markdown]
# ### 3. Data Visualization:
#
# Goal: Create visual representations of your findings.
# Steps and Hints:
# Heatmaps: Use heatmaps to visualize correlation matrices. This can be done with seaborn.
# Multi-dimensional Scatter Plots: Create scatter plots for pairs of variables to explore their relationships. seaborn’s pairplot is useful here.
# Fourier Transform Visualizations: Plot the amplitude vs. frequency graphs for the Fourier transformed data.
# Tools: Utilize matplotlib and seaborn for creating plots.

# %%
# Heatmap for correlation matrix
plt.figure(figsize=(9, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation matrix heatmap')
plt.show()

# Multi-dimensional Scatter Plots (Pairplot)
sns.pairplot(ninja_data, height=2, diag_kind='kde')
plt.suptitle('Pairplot of variables', y=1.02)
plt.show()

# Fourier Transform Visualizations (Amplitude vs. Frequency)
fourier_transform = np.fft.fft(ninja_data['Temperature'])
frequency = np.fft.fftfreq(len(fourier_transform))
plt.figure(figsize=(10, 5))
plt.plot(frequency[:len(frequency)//2], np.abs(fourier_transform)[:len(frequency)//2])
plt.title('Amplitude vs. frequency - Fourier transform of temperature data')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()

# Plotting the original and transformed data
plt.figure(figsize=(10, 6))

# Original Data
plt.subplot(2, 2, 1)
plt.plot(ninja_data['Time'], ninja_data['Temperature'])
plt.title('Original Temperature Data')

# Normalized Data
plt.subplot(2, 2, 2)
plt.plot(normalized_data['Time'], normalized_data['Temperature'])
plt.title('Normalized Temperature Data')

# Logarithmic Scaled Data
plt.subplot(2, 2, 3)
plt.plot(log_scaled_data['Time'], log_scaled_data['Temperature'])
plt.title('Logarithmic Scaled Temperature Data')
# Out:
# Text(0.5, 1.0, 'Logarithmic Scaled Temperature Data')

# %% [markdown]
# ### Interpretation:
#
# Goal: Write a brief report interpreting the results of your analyses.
# Steps and Hints:
# Discuss Findings: Interpret the results of your statistical analyses and visualizations. Consider real-world implications or applications of your findings.
# Relate to Real-World: Think about how these insights can be applied in practical scenarios or how they align with theoretical knowledge.
# Reflect on the Process: Comment on what the data transformations and analyses reveal about the nature of the dataset.

# %% [markdown]
# 1. Data Transformation:
# - Normalization: The data has been normalized, ensuring that each variable now has a mean of 0 and a standard deviation of 1. This facilitates comparisons between variables with different scales.
# - Logarithmic Scaling: Logarithmic scaling has been applied to handle wide-ranging values, enhancing the interpretability of the data.
# - Fourier Transformation: Fourier transformation has been employed to analyze frequency components in the time-series data, providing insights into patterns and periodicities.
#
# 2. Statistical Analysis:
# - Descriptive Statistics: The descriptive statistics offer a comprehensive overview of the dataset, including measures such as mean, standard deviation, and quartiles.
# - Correlation Analysis: The correlation matrix reveals relationships between variables. For instance, the correlation between temperature and time might indicate a temporal pattern.
# - Linear Regression: A linear regression analysis has been conducted, showing the relationship between temperature and time. The significant p-value suggests a meaningful association.
#
# 3. Data Visualization:
#
# - Heatmap: The heatmap of the correlation matrix visually emphasizes the strength and direction of relationships between variables.
# - Multi-dimensional Scatter Plots (Pairplot): The pairplot provides a graphical representation of relationships between pairs of variables, aiding in identifying potential patterns or trends.
# - Fourier Transform Visualization: The amplitude vs. frequency graph showcases the frequency components in the temperature data, offering insights into periodic behaviors.
#
# **Interpretation:**
#
# The heatmap suggests strong correlations between certain variables, highlighting potential dependencies that might be further explored.
# The pairplot indicates potential linear relationships between some pairs of variables, guiding future analyses or modeling efforts.
# The Fourier transform visualization identifies dominant frequencies in the temperature data, contributing to understanding cyclic patterns.
#
# **Real-World Implications:**
#
# Insights from these analyses could be invaluable in various fields. For instance, understanding temperature patterns over time can inform climate-related studies or guide temperature-sensitive processes in industries.
# Reflection on the Process:
#
# The transformation and analysis process unveiled the intricate nature of the dataset. The combination of statistical techniques and visualizations provided a holistic understanding, laying the groundwork for more targeted investigations.
#
# **Conclusion:**
#
# The conducted analyses and visualizations provide a robust foundation for understanding the dataset. Further, these insights can be leveraged to make informed decisions or guide additional analyses tailored to specific objectives.
# This report encapsulates the key findings and implications derived from the exploratory data analysis, statistical analyses, and visualizations performed on the provided dataset.
