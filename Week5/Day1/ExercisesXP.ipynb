# %% [markdown]
# # Exercises XP

# %% [markdown]
# ## Exercise 1 : Understanding Data Visualization
# Instructions
# Explain why data visualization is important in data analysis.
# Describe the purpose of a line graph in data visualization.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# Data visualization is not just about making pretty graphs; it’s about making data easier to understand and interpret. It helps in identifying patterns, trends, and anomalies, making complex data more accessible.
# Getting why data visualization matters leads us to check out the various graph types. Each designed to highlight specific aspects of data, thereby transforming raw numbers into visual stories that are easier to comprehend and analyze.
#
#  Line Graph
#
# Purpose: Line plots are used to display quantitative values over a continuous interval or time span. They are ideal for showing trends and changes over time.
# How It’s Constructed: Points representing data values are plotted and connected by straight line segments.
# Visual Appearance: It appears as a series of points connected by lines. Often, the x-axis represents time.

# %% [markdown]
# ## Exercise 2 : Creating A Line Plot For Temperature Variation
# Instructions
# Create a simple line plot using Matplotlib that represents the temperature variations over a week.
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]) and label the x-axis as “Day” and the y-axis as “Temperature (°F)”.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
temp_values = [72, 74, 76, 80, 82, 78, 75]
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.plot(days, temp_values, marker='o', linestyle='-', color='b')

plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Temperature variations over a week')

plt.show()

# %% [markdown]
# ## Exercise 3 : Visualizing Monthly Sales With A Bar Chart
# Instructions
# Generate a bar chart using Matplotlib to visualize the monthly sales data for a retail store.
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]) and label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.

# %%
sales = [5000, 5500, 6200, 7000, 7500]
months = ['January', 'February', 'March', 'April', 'May']

plt.bar(months, sales, color='green')

plt.xlabel('Month')
plt.ylabel('Sales amount ($)')
plt.title('Monthly sales data for retail store')

plt.show()

# %% [markdown]
# ##  Exercise 4 : Data Visualisation
# Instructions
# Using the dataset sales_data.csv
#
# Calculate the total quantity of products sold by the company.
# Identify the category that had the highest revenue and calculate how much revenue it generated.
# Determine the average revenue per sale in the dataset.
# Create a bar chart to visualize the total revenue generated in each quarter of the year (Q1, Q2, Q3, Q4).

# %%
df = pd.read_csv('sales_data.csv')
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      369 non-null    object
#  1   product   369 non-null    object
#  2   category  369 non-null    object
#  3   price     367 non-null    float64
#  4   quantity  368 non-null    float64
#  5   revenue   368 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.4+ KB
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# 5  2022-01-05       Watch  Accessories   150.0      10.0   1500.0
# 6  2022-01-06  Smartphone  Electronics   600.0       8.0   4800.0
# 7  2022-01-06      Tablet  Electronics   400.0       5.0   2000.0
# 8  2022-01-07        Coat     Clothing   100.0      10.0   1000.0
# 9  2022-01-08  Smartwatch  Accessories   200.0      12.0   2400.0

# %%
# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

total_quantity = df['quantity'].sum()
print(f'Total quantity of products sold: {total_quantity}')
# Out:
# Total quantity of products sold: 5360.0

# %%
category = df.groupby('category')['revenue'].sum().idxmax()
highest_revenue = df.groupby('category')['revenue'].sum().max()
print(f'Category with the highest revenue: {category}, revenue: {highest_revenue}')
# Out:
# Category with the highest revenue: Electronics, revenue: 516080.0

# %%
df['quarter'] = df['date'].dt.quarter
avg_revenue = df.groupby('quarter')['revenue'].mean()
print('Average revenue per sale in each quarter:')
print(avg_revenue)
# Out:
# Average revenue per sale in each quarter:
# quarter
# 1    1979.347826
# 2    2044.111111
# 3    2148.695652
# 4    2070.000000
# Name: revenue, dtype: float64

# %%
revenue_quarter = df.groupby('quarter')['revenue'].sum()

plt.bar(['Q1', 'Q2', 'Q3', 'Q4'], revenue_quarter, color='salmon')

plt.xlabel('Quarter')
plt.ylabel('Total revenue')
plt.title('Total revenue generated in each quarter of the year')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# ## Exercise 5 : Data Visualisation Using MatPlotLib
# Instructions
# Create a simple line plot using Matplotlib. Plot the function y = x^2 for x values ranging from -10 to 10. Add a title and label the x and y axes.
# Generate a bar chart to display the sales data of four different products (A, B, C, D) in a week. The sales values are 15, 30, 45, and 20 respectively. Label the chart appropriately.
# Create a pie chart representing the following data about favorite fruits of a group of people: Apples (40%), Bananas (30%), Cherries (20%), and Dates (10%). Customize the chart with different colors for each fruit and add a legend.

# %%
# Line plot
x_values = np.linspace(-10, 10, 100)
y_values = x_values**2

plt.plot(x_values, y_values, label='y = x^2')
plt.title('Line plot: y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Bar Chart
products = ['A', 'B', 'C', 'D']
sales_values = [15, 30, 45, 20]

plt.bar(products, sales_values, color=['blue', 'lightgreen', 'coral', 'lightsalmon'])
plt.title('Weekly sales data')
plt.xlabel('Products')
plt.ylabel('Sales')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Pie chart
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['gold', 'lightcoral', 'skyblue', 'green']

plt.pie(percentages, labels=fruits, autopct='%1.1f%%', colors=colors, startangle=90, explode = (0.1, 0, 0, 0))
plt.title('Favorite Fruits Distribution')
plt.legend(loc='best')
plt.show()
